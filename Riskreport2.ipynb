# %%
import pandas as pd
import numpy as np
import QuantLib as ql
import datetime as dt

# %%
df=pd.read_csv('sample_portfolio.csv')
print(df.head)
# Out:
# <bound method NDFrame.head of     SecurityID   IssueDate FirstSettlementDate AccrualDate DaycountBasisType  \
# 0            1   5/15/2020           5/15/2020   5/15/2020     Actual/Actual
# 1            2    6/1/2020            6/1/2020   5/15/2020     Actual/Actual
# 2            3   7/31/2019           7/31/2019   7/31/2019     Actual/Actual
# 3            4   5/15/2020           5/15/2020   5/15/2020     Actual/Actual
# 4            5   7/31/2020           7/31/2020   7/31/2020     Actual/Actual
# 5            7   7/31/2020           7/31/2020   7/31/2020     Actual/Actual
# 6            9  11/16/2020          11/16/2020  11/15/2020     Actual/Actual
# 7           10    2/1/2021            2/1/2021   1/31/2021     Actual/Actual
# 8           11   2/16/2021           2/16/2021   2/15/2021     Actual/Actual
# 9           12   2/16/2021           2/16/2021   2/15/2021     Actual/Actual
# 10          13    3/1/2021            3/1/2021   2/15/2021     Actual/Actual
# 11          14   1/31/2020           1/31/2020   1/31/2020     Actual/Actual
# 12          16    2/1/2021            2/1/2021   1/31/2021     Actual/Actual
# 13          18  12/31/2020          12/31/2020  12/31/2020     Actual/Actual
# 14          20  11/16/2020          11/16/2020  11/15/2020     Actual/Actual
# 15          21  11/30/2020          11/30/2020  11/15/2020     Actual/Actual
# 16          22    3/1/2021            3/1/2021   2/28/2021     Actual/Actual
# 17          24    3/2/2020            3/2/2020   2/29/2020     Actual/Actual
# 18          25    3/1/2021            3/1/2021   2/28/2021     Actual/Actual
# 19          26   8/31/2020           8/31/2020   8/31/2020     Actual/Actual
# 20          27   6/30/2020           6/30/2020   6/30/2020     Actual/Actual
# 21          28   4/30/2020           4/30/2020   4/30/2020     Actual/Actual
# 22          29   3/31/2020           3/31/2020   3/31/2020     Actual/Actual
# 23          30   9/30/2020           9/30/2020   9/30/2020     Actual/Actual
# 24          31    6/1/2020            6/1/2020   5/31/2020     Actual/Actual
# 25          34   3/31/2021           3/31/2021   3/31/2021     Actual/Actual
# 26          35   3/31/2021           3/31/2021   3/31/2021     Actual/Actual
# 27          37   4/30/2021           4/30/2021   4/30/2021     Actual/Actual
# 28          39   4/30/2021           4/30/2021   4/30/2021     Actual/Actual
# 29          40   5/17/2021           5/17/2021   5/15/2021     Actual/Actual
# 30          41   5/17/2021           5/17/2021   5/15/2021     Actual/Actual
# 31          42   5/17/2021           5/17/2021   5/15/2021     Actual/Actual
# 32          43    6/1/2021            6/1/2021   5/15/2021     Actual/Actual
# 33          45    6/1/2021            6/1/2021   5/31/2021     Actual/Actual
# 34          46    6/1/2021            6/1/2021   5/31/2021     Actual/Actual
# 35          47   6/15/2021           6/15/2021   6/15/2021     Actual/Actual
# 36          49   6/30/2021           6/30/2021   6/30/2021     Actual/Actual
# 37          50   6/30/2021           6/30/2021   6/30/2021     Actual/Actual
# 38          51   7/15/2021           7/15/2021   7/15/2021     Actual/Actual
# 39          53    8/2/2021            8/2/2021   7/31/2021     Actual/Actual
# 40          54    8/2/2021            8/2/2021   7/31/2021     Actual/Actual
# 41          55   8/16/2021           8/16/2021   8/15/2021     Actual/Actual
# 42          56   8/16/2021           8/16/2021   8/15/2021     Actual/Actual
# 43          57   8/16/2021           8/16/2021   8/15/2021     Actual/Actual
# 44          58   8/31/2021           8/31/2021   8/15/2021     Actual/Actual
# 45          60   8/31/2021           8/31/2021   8/31/2021     Actual/Actual
# 46          61   8/31/2021           8/31/2021   8/31/2021     Actual/Actual
# 47          62   9/15/2021           9/15/2021   9/15/2021     Actual/Actual
# 48          63   9/30/2021           9/30/2021   9/30/2021     Actual/Actual
# 49          65   9/30/2021           9/30/2021   9/30/2021     Actual/Actual
#
#    CouponType  Coupon FirstCouponDate InterestPaymentFrequency MaturityDate  \
# 0         FIX   1.500      11/15/2020             Semiannually    5/15/2050
# 1         FIX   1.375      11/15/2020             Semiannually    5/15/2040
# 2         FIX   2.000       1/31/2020             Semiannually    7/31/2024
# 3         FIX   0.875      11/15/2020             Semiannually    5/15/2030
# 4         FIX   0.500       1/31/2021             Semiannually    7/31/2025
# 5         FIX   0.625       1/31/2021             Semiannually    7/31/2027
# 6         FIX   1.125       5/15/2021             Semiannually   11/15/2030
# 7         FIX   0.625       7/31/2021             Semiannually    1/31/2026
# 8         FIX   1.375       8/15/2021             Semiannually    2/15/2031
# 9         FIX   2.125       8/15/2021             Semiannually    2/15/2051
# 10        FIX   2.125       8/15/2021             Semiannually    2/15/2041
# 11        FIX   1.625       7/31/2020             Semiannually    1/31/2025
# 12        FIX   1.000       7/31/2021             Semiannually    1/31/2028
# 13        FIX   0.875       6/30/2021             Semiannually   12/31/2027
# 14        FIX   1.875       5/15/2021             Semiannually   11/15/2050
# 15        FIX   1.625       5/15/2021             Semiannually   11/15/2040
# 16        FIX   0.750       8/31/2021             Semiannually    2/28/2026
# 17        FIX   1.375       8/31/2020             Semiannually    2/28/2025
# 18        FIX   1.375       8/31/2021             Semiannually    2/29/2028
# 19        FIX   0.500       2/28/2021             Semiannually    8/31/2025
# 20        FIX   0.500      12/31/2020             Semiannually    6/30/2025
# 21        FIX   0.625      10/31/2020             Semiannually    4/30/2025
# 22        FIX   0.250       9/30/2020             Semiannually    3/31/2025
# 23        FIX   0.250       3/31/2021             Semiannually    9/30/2025
# 24        FIX   0.250      11/30/2020             Semiannually    5/31/2025
# 25        FIX   0.500       9/30/2021             Semiannually    3/31/2026
# 26        FIX   1.000       9/30/2021             Semiannually    3/31/2028
# 27        FIX   0.500      10/31/2021             Semiannually    4/30/2026
# 28        FIX   1.000      10/31/2021             Semiannually    4/30/2028
# 29        FIX   1.375      11/15/2021             Semiannually    5/15/2031
# 30        FIX   0.250      11/15/2021             Semiannually    5/15/2024
# 31        FIX   2.125      11/15/2021             Semiannually    5/15/2051
# 32        FIX   2.000      11/15/2021             Semiannually    5/15/2041
# 33        FIX   0.500      11/30/2021             Semiannually    5/31/2026
# 34        FIX   1.000      11/30/2021             Semiannually    5/31/2028
# 35        FIX   0.250      12/15/2021             Semiannually    6/15/2024
# 36        FIX   0.625      12/31/2021             Semiannually    6/30/2026
# 37        FIX   1.000      12/31/2021             Semiannually    6/30/2028
# 38        FIX   0.250       1/15/2022             Semiannually    7/15/2024
# 39        FIX   0.375       1/31/2022             Semiannually    7/31/2026
# 40        FIX   0.750       1/31/2022             Semiannually    7/31/2028
# 41        FIX   0.250       2/15/2022             Semiannually    8/15/2024
# 42        FIX   1.000       2/15/2022             Semiannually    8/15/2031
# 43        FIX   1.750       2/15/2022             Semiannually    8/15/2051
# 44        FIX   1.500       2/15/2022             Semiannually    8/15/2041
# 45        FIX   0.500       2/28/2022             Semiannually    8/31/2026
# 46        FIX   0.875       2/28/2022             Semiannually    8/31/2028
# 47        FIX   0.250       3/15/2022             Semiannually    9/15/2024
# 48        FIX   0.625       3/31/2022             Semiannually    9/30/2026
# 49        FIX   1.000       3/31/2022             Semiannually    9/30/2028
#
#     Unnamed: 10       Date    Price  PositionNotional   Unnamed: 14
# 0           NaN  10/7/2021   81.129            711,000          NaN
# 1           NaN  10/7/2021   85.852            589,000          NaN
# 2           NaN  10/7/2021  103.516            486,000          NaN
# 3           NaN  10/7/2021   93.153            572,000          NaN
# 4           NaN  10/7/2021   98.054            887,000          NaN
# 5           NaN  10/7/2021  100.104            784,000          NaN
# 6           NaN  10/7/2021   95.666            776,000          NaN
# 7           NaN  10/7/2021   99.750              9,000          NaN
# 8           NaN  10/7/2021   94.610            512,000          NaN
# 9           NaN  10/7/2021   97.816             47,000          NaN
# 10          NaN  10/7/2021   96.518            517,000          NaN
# 11          NaN  10/7/2021   94.625            933,000          NaN
# 12          NaN  10/7/2021   97.108            400,000          NaN
# 13          NaN  10/7/2021  102.485            649,000          NaN
# 14          NaN  10/7/2021  100.039            230,000          NaN
# 15          NaN  10/7/2021   96.968            579,000          NaN
# 16          NaN  10/7/2021   99.430            402,000          NaN
# 17          NaN  10/7/2021   96.325            267,000          NaN
# 18          NaN  10/7/2021   99.493            111,000          NaN
# 19          NaN  10/7/2021   89.071            504,000          NaN
# 20          NaN  10/7/2021   89.265             80,000          NaN
# 21          NaN  10/7/2021   98.259              2,000          NaN
# 22          NaN  10/7/2021   99.958            974,000          NaN
# 23          NaN  10/7/2021  101.577            274,000          NaN
# 24          NaN  10/7/2021   99.285            557,000          NaN
# 25          NaN  10/7/2021   97.977            140,000          NaN
# 26          NaN  10/7/2021   98.227            997,000          NaN
# 27          NaN  10/7/2021   98.816            874,000          NaN
# 28          NaN  10/7/2021   99.421            917,000          NaN
# 29          NaN  10/7/2021   97.837            997,000          NaN
# 30          NaN  10/7/2021   98.346            307,000          NaN
# 31          NaN  10/7/2021   99.659            174,000          NaN
# 32          NaN  10/7/2021   99.938            662,000          NaN
# 33          NaN  10/7/2021   99.277            727,000          NaN
# 34          NaN  10/7/2021   99.903            228,000          NaN
# 35          NaN  10/7/2021   99.830            207,000          NaN
# 36          NaN  10/7/2021   99.169             78,000          NaN
# 37          NaN  10/7/2021   99.953            132,000          NaN
# 38          NaN  10/7/2021   99.854            812,000          NaN
# 39          NaN  10/7/2021  100.879            734,000          NaN
# 40          NaN  10/7/2021   99.509            707,000          NaN
# 41          NaN  10/7/2021  105.883             30,000          NaN
# 42          NaN  10/7/2021  103.272            688,000          NaN
# 43          NaN  10/7/2021   99.875            227,000          NaN
# 44          NaN  10/7/2021   99.081            329,000          NaN
# 45          NaN  10/7/2021   99.748            883,000          NaN
# 46          NaN  10/7/2021   99.351            833,000          NaN
# 47          NaN  10/7/2021   99.867            626,000          NaN
# 48          NaN  10/7/2021   99.570            754,000          NaN
# 49          NaN  10/7/2021   99.635            414,000          NaN  >

# %%
#Need to convert PositionNotional column to float
df[' PositionNotional ']=df[' PositionNotional '].str.replace(',', '').astype(int)

# %%
#drop null columns
df=df.drop(['Unnamed: 10','Unnamed: 14'],axis=1)
df.head()
# Out:
#    SecurityID  IssueDate FirstSettlementDate AccrualDate DaycountBasisType  \
# 0           1  5/15/2020           5/15/2020   5/15/2020     Actual/Actual
# 1           2   6/1/2020            6/1/2020   5/15/2020     Actual/Actual
# 2           3  7/31/2019           7/31/2019   7/31/2019     Actual/Actual
# 3           4  5/15/2020           5/15/2020   5/15/2020     Actual/Actual
# 4           5  7/31/2020           7/31/2020   7/31/2020     Actual/Actual
#
#   CouponType  Coupon FirstCouponDate InterestPaymentFrequency MaturityDate  \
# 0        FIX   1.500      11/15/2020             Semiannually    5/15/2050
# 1        FIX   1.375      11/15/2020             Semiannually    5/15/2040
# 2        FIX   2.000       1/31/2020             Semiannually    7/31/2024
# 3        FIX   0.875      11/15/2020             Semiannually    5/15/2030
# 4        FIX   0.500       1/31/2021             Semiannually    7/31/2025
#
#         Date    Price   PositionNotional
# 0  10/7/2021   81.129              711000
# 1  10/7/2021   85.852              589000
# 2  10/7/2021  103.516              486000
# 3  10/7/2021   93.153              572000
# 4  10/7/2021   98.054              887000

# %%
def one_bond(row):
    """
    function to process one fixed coupon bond (Actual/Actual, Semi-annual coupons)
    ---
    input: one row from data frame
    ---
    output: YTM, Modified Duration, Dirty Price, Maturity Bucket
    """

    d=dt.datetime.strptime(row['Date'], "%m/%d/%Y")
    valuationDate = ql.Date(d.day,d.month,d.year)
    ql.Settings.instance().evaluationDate = valuationDate
    
    d=dt.datetime.strptime(row['AccrualDate'], "%m/%d/%Y")
    start = ql.Date(d.day,d.month,d.year)
    
    d=dt.datetime.strptime(row['MaturityDate'], "%m/%d/%Y")
    maturity = ql.Date(d.day,d.month,d.year)
    
    #time till maturity from valuation date
    TTM = ql.ActualActual().yearFraction(valuationDate, maturity)
    if TTM <= 5:
        mat_bucket = '5Y'
    elif TTM <= 10:
        mat_bucket = '10Y'
    elif TTM <= 20:
        mat_bucket = '20Y'
    elif TTM <= 30:
        mat_bucket = '30Y'
        
    calendar = ql.UnitedStates()
    frequency = ql.Semiannual
    tenor = ql.Period(frequency)
    dateGeneration = ql.DateGeneration.Backward
    monthEnd = True if d.day in [28,29,30,31] else False
    schedule = ql.Schedule (start, maturity, tenor, calendar, ql.Unadjusted, ql.Unadjusted, dateGeneration, monthEnd)
    daycount = ql.ActualActual(ql.ActualActual.ISMA,schedule)
    
    settlementDays = 0
    price=row['Price']
    face=100
    coupon = row['Coupon']/100
    
    bond = ql.FixedRateBond(settlementDays, face, schedule, [coupon], daycount)
    ytm = bond.bondYield(price, daycount, ql.Compounded, frequency, valuationDate,1.0e-10)
    
    rate = ql.InterestRate(ytm, daycount, ql.Compounded, frequency)
    ModDur = ql.BondFunctions.duration(bond,rate,ql.Duration.Modified)
    conv = ql.BondFunctions.convexity(bond, rate)
    dirty_p = bond.dirtyPrice(ytm, daycount, ql.Compounded, frequency)
    
    return pd.Series([ytm, ModDur, conv,dirty_p,mat_bucket],index=["YTM","Duration","Convexity","DirtyPrice","Maturity_Bucket"])

# %%
#apply function to calculate YTM, duration, market price and maturity bucket for all bonds in portfolio
newdf=df.apply(one_bond, axis=1)
#newdf.rename(columns={0: "YTM", 1: "Duration",2:"DirtyPrice",3:'Maturity_Bucket'},inplace=True)
newdf.head()
# Out:
#         YTM   Duration   Convexity  DirtyPrice Maturity_Bucket
# 0  0.024176  22.214100  588.682351   81.720033             30Y
# 1  0.023151  15.978642  288.258546   86.393780             20Y
# 2  0.007356   2.733512    8.959287  103.885565              5Y
# 3  0.017349   8.193546   73.062372   93.497769             10Y
# 4  0.010213   3.760832   16.100793   98.146391              5Y

# %%
df=pd.concat([df,newdf],axis=1)
df.head()
# Out:
#    SecurityID  IssueDate FirstSettlementDate AccrualDate DaycountBasisType  \
# 0           1  5/15/2020           5/15/2020   5/15/2020     Actual/Actual
# 1           2   6/1/2020            6/1/2020   5/15/2020     Actual/Actual
# 2           3  7/31/2019           7/31/2019   7/31/2019     Actual/Actual
# 3           4  5/15/2020           5/15/2020   5/15/2020     Actual/Actual
# 4           5  7/31/2020           7/31/2020   7/31/2020     Actual/Actual
#
#   CouponType  Coupon FirstCouponDate InterestPaymentFrequency MaturityDate  \
# 0        FIX   1.500      11/15/2020             Semiannually    5/15/2050
# 1        FIX   1.375      11/15/2020             Semiannually    5/15/2040
# 2        FIX   2.000       1/31/2020             Semiannually    7/31/2024
# 3        FIX   0.875      11/15/2020             Semiannually    5/15/2030
# 4        FIX   0.500       1/31/2021             Semiannually    7/31/2025
#
#         Date    Price   PositionNotional        YTM   Duration   Convexity  \
# 0  10/7/2021   81.129              711000  0.024176  22.214100  588.682351
# 1  10/7/2021   85.852              589000  0.023151  15.978642  288.258546
# 2  10/7/2021  103.516              486000  0.007356   2.733512    8.959287
# 3  10/7/2021   93.153              572000  0.017349   8.193546   73.062372
# 4  10/7/2021   98.054              887000  0.010213   3.760832   16.100793
#
#    DirtyPrice Maturity_Bucket
# 0   81.720033             30Y
# 1   86.393780             20Y
# 2  103.885565              5Y
# 3   93.497769             10Y
# 4   98.146391              5Y

# %%
#DV01=Modified Duration*0.01 * MarketPrice*0.01
df['DV01']=df['DirtyPrice']/100*df[' PositionNotional ']*df['Duration']*0.0001

# %%
#check and verify day count between any two semi-annual coupon payments is 184 
ql.ActualActual().dayCount(ql.Date(28, 2, 2021), ql.Date(31, 8, 2021))
# Out:
# 184

# %%
#number of days from 10/7/2021 to 10/12/2021
ndays=ql.Date(12, 10, 2021)-ql.Date(7, 10, 2021)
ndays
# Out:
# 5

# %%
#Calculate Accrued Interest on 10/7/2021
AccruedInterest_10_07=(df['DirtyPrice'] - df['Price'])/100 * df[' PositionNotional ']

#Accrued Interest on 10/12/2021
df['AccruedInterest_10.12']=AccruedInterest_10_07 + df['Coupon']/100/2 * df[' PositionNotional '] * ndays/184

# %%
df.head()
# Out:
#    SecurityID  IssueDate FirstSettlementDate AccrualDate DaycountBasisType  \
# 0           1  5/15/2020           5/15/2020   5/15/2020     Actual/Actual
# 1           2   6/1/2020            6/1/2020   5/15/2020     Actual/Actual
# 2           3  7/31/2019           7/31/2019   7/31/2019     Actual/Actual
# 3           4  5/15/2020           5/15/2020   5/15/2020     Actual/Actual
# 4           5  7/31/2020           7/31/2020   7/31/2020     Actual/Actual
#
#   CouponType  Coupon FirstCouponDate InterestPaymentFrequency MaturityDate  \
# 0        FIX   1.500      11/15/2020             Semiannually    5/15/2050
# 1        FIX   1.375      11/15/2020             Semiannually    5/15/2040
# 2        FIX   2.000       1/31/2020             Semiannually    7/31/2024
# 3        FIX   0.875      11/15/2020             Semiannually    5/15/2030
# 4        FIX   0.500       1/31/2021             Semiannually    7/31/2025
#
#         Date    Price   PositionNotional        YTM   Duration   Convexity  \
# 0  10/7/2021   81.129              711000  0.024176  22.214100  588.682351
# 1  10/7/2021   85.852              589000  0.023151  15.978642  288.258546
# 2  10/7/2021  103.516              486000  0.007356   2.733512    8.959287
# 3  10/7/2021   93.153              572000  0.017349   8.193546   73.062372
# 4  10/7/2021   98.054              887000  0.010213   3.760832   16.100793
#
#    DirtyPrice Maturity_Bucket         DV01  AccruedInterest_10.12
# 0   81.720033             30Y  1290.704582            4347.146858
# 1   86.393780             20Y   813.088145            3301.121119
# 2  103.885565              5Y   138.010628            1928.152185
# 3   93.497769             10Y   438.196745            2040.081755
# 4   98.146391              5Y   327.402384             879.768910

# %%
#2.Aggregate DV01,PositionNotional,Accrued Interest on the maturity buckets
aggdf = df.groupby('Maturity_Bucket').agg({'DV01':'sum',' PositionNotional ':'sum','AccruedInterest_10.12':'sum'})
aggdf
# Out:
#                         DV01   PositionNotional   AccruedInterest_10.12
# Maturity_Bucket
# 10Y              6910.999158             9717000           24605.417386
# 20Y              4138.454677             2676000           15042.275819
# 30Y              2809.330297             1389000            8395.605498
# 5Y               4364.430084            11547000           13386.234875

# %%
#3.Stress testing with duration only
port_dv01 = aggdf['DV01'].sum()
port_dv01
# Out:
# 18223.21421601281

# %%
test = np.array([-25,-20,-15,-10,-5,5,10,15,20,25])
p_and_l = np.round(-test*port_dv01, 2) 
cols=[str(bps)+'bps' for bps in test]
pd.DataFrame([p_and_l],columns=cols,index=['Portfolio P&L'] )
# Out:
#                   -25bps     -20bps     -15bps     -10bps     -5bps      5bps  \
# Portfolio P&L  455580.36  364464.28  273348.21  182232.14  91116.07 -91116.07
#
#                    10bps      15bps      20bps      25bps
# Portfolio P&L -182232.14 -273348.21 -364464.28 -455580.36

# %%
#3. P&L with duration and convexity
def cal_p_and_l(data):
    """
    input:a row from dataframe
    output: p&l
    """
    duration = data['Duration']
    conv = data['Convexity']
    test = np.array([-25,-20,-15,-10,-5,5,10,15,20,25])
    p_and_l = (-test/10000*duration + 0.5*conv*(test/10000)**2)*data['DirtyPrice']/100*data[' PositionNotional ']
    cols=[str(bps)+'bps' for bps in test]
    
    return pd.Series(p_and_l,index=cols)

# %%
p_l = df.apply(cal_p_and_l, axis=1)
port_p_l = pd.DataFrame([p_l.sum(axis=0)], index=['Portfolio P&L'])
np.round(port_p_l,2)
# Out:
#                   -25bps     -20bps     -15bps    -10bps     -5bps      5bps  \
# Portfolio P&L  462690.11  369014.52  275907.72  183369.7  91400.46 -90831.68
#
#                    10bps     15bps      20bps     25bps
# Portfolio P&L -181094.58 -270788.7 -359914.04 -448470.6
